# %% [markdown]
# An **algorithm** is a process or sequence of steps used to solve a problem or calculation, primarily used computers.

# %% [markdown]
# Popular Examples:
# - Lego and Ikea instructions sheets for building

# %% [markdown]
# **Developing Algorithms**
# - Always have a plan; never start without having a plan.
# - Exception: exploring a New API
#
# ***Techniques to Developing Algorithms***
# - Better to write down steps in programming terms,a process know as Pseudocode.
#     - Be very descriptive, review each step to avoid operational assumptions.
# - Flowcharting, a visual flow ppresetation of the algo using symbols.
#     - More formal the pseudocode
#     - shows the flwo or execution path of an algorithm better than pseudocode.
#
#
# Key Takeway - easier to erase a line in flowchatting or delete a sentence in pseudocode that it is to **rewrite the actual code**

# %%
#Pseudocode_example

'''Get and display two numbers from user'''

#ask user for each input
#assign values to variables
#print variables

num_1 = input("Enter 1st Number:")
num_2 = input("Enter 2nd Number:")

print(f"You've selected {num_1} and {num_2}. Thank you")
# Out:
# You've selected 21342 and 244002. Thank you
