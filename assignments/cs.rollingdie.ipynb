# %% [markdown]
# # Probability: Rolling a die
#
# - Write a program that simulates a user rolling a single die a user-defined number of times. The program should prompt the user to enter how many times the die will be rolled and which die value they want to track. After the simulation, the program should display how many times the specified value appears and how many times the die has been rolled.

# %%
#initialize the die value counter per roll
value_freq = 0

#set inputs for the user
user_rolls = int(input('Enter the number of times to roll the die:'))
user_value = int(input('Enter a die value (1 - 6:)'))

#set for loop to iterate based on the input value user_rolls
for x in range(user_rolls):
#no seed value for complete randomness
  if random.randint(1,6) == user_value:
    value_freq += 1

print(f'Die Value Selected: {user_value}\nFrequency(#): {value_freq}\nFrequency(%): {round((value_freq/user_rolls),2)*100}%\n\nTotal Rolls (Single Die): {user_rolls}')
# Out:
# Die Value Selected: 4
# Frequency(#): 581822
# Frequency(%): 17.0%
#
# Total Rolls (Single Die): 3494897
