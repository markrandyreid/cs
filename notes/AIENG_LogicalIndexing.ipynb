# %% [markdown]
# # Logical Indexing
# - filtering data based on some numeric value using logical expression (boolean values)
# - Rather than looping thru each value to check, we simply use one line of code (example below)

# %%
#Extract all italian cities from the dataframe below
import pandas as pd

info = [
    ['Chicago', 'the United States'],
    ['Boston', 'the United States'],
    ['New York City', 'the United States'],
    ['Paris', 'France'],
    ['Rome', 'Italy'],
    ['Venice', 'Italy'],
    ['Milan', 'Italy'],
    ['Madrid', 'Spain'],
    ['Barcelona', 'Spain']
]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 #Extract all italian cities from the dataframe below
# ----> 2 import pandas as pd
#       4 info = [
#       5     ['Chicago', 'the United States'],
#       6     ['Boston', 'the United States'],
#    (...)     13     ['Barcelona', 'Spain']
#      14 ]
#
# ModuleNotFoundError: No module named 'pandas'
